# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset in a  Pandas DataFrame and explore the data.

file_path = 'C:\\Users\\user\\Africa-Data-School-Curriculum\\notebooks/data/jumta.csv'
df = pd.read_csv(file_path)
print(df)

# line plot of the monthly revenue.
plt.figure(figsize=(10, 5))
plt.plot(df['Month'], df['Revenue'], marker='s', linestyle='-', linewidth=2, label='Revenue')
plt.title('Monthly Revenue (2020-2021)')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.grid()
plt.legend()
plt.show()


# Bar plot of the total number of orders per month.

plt.figure(figsize=(10, 5))
plt.bar(df['Month'], df['Orders'], color='orange', label='Orders')
plt.title('Monthly Orders (2020-2021)')
plt.xlabel('Month')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend()
plt.show()
# Out:
#        Month Revenue  Orders  Average_Order_Value
# 0   Jan-2020  10,000     200                   50
# 1   Feb-2020  11,000     220                   50
# 2   Mar-2020  12,000     240                   50
# 3   Apr-2020  13,000     260                   50
# 4   May-2020  14,000     280                   50
# 5   Jun-2020  15,000     300                   50
# 6   Jul-2020  16,000     320                   50
# 7   Aug-2020  17,000     340                   50
# 8   Sep-2020  18,000     360                   50
# 9   Oct-2020  19,000     380                   50
# 10  Nov-2020  20,000     400                   50
# 11  Dec-2020  21,000     420                   50
# 12  Jan-2021  22,000     440                   50
# 13  Feb-2021  23,000     460                   50
# 14  Mar-2021  24,000     480                   50
# 15  Apr-2021  25,000     500                   50
# 16  May-2021  26,000     520                   50
# 17  Jun-2021  27,000     540                   50
# ...
